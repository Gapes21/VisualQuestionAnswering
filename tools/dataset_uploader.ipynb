# %%
from datasets import load_dataset
from huggingface_hub import login

# %%
login("")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to C:\Users\subha\.cache\huggingface\token
# Login successful

# %%
dataset = load_dataset("imagefolder", data_dir = "./Dataset")
print(dataset["train"][0])
# Out:
# Resolving data files:   0%|          | 0/20645 [00:00<?, ?it/s]
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427 at 0x265A9EF3F40>, 'qna': [{'question': 'Are the creatures in this image predators or prey animals?', 'answer': 'prey', 'answerlabel': 39617}, {'question': 'What type of animal is in the photo?', 'answer': 'zebra', 'answerlabel': 56636}, {'question': 'How many animals are here?', 'answer': '3', 'answerlabel': 2019}, {'question': 'Do the zebras blend in with their surrounding?', 'answer': 'yes', 'answerlabel': 56366}, {'question': 'How many zebras are in the picture?', 'answer': '3', 'answerlabel': 2019}, {'question': 'Do the zebras eat grass?', 'answer': 'no', 'answerlabel': 32111}]}

# %%
dataset.push_to_hub("Gapes21/VQA_Random")
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/30 [00:00<?, ?ba/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/Gapes21/VQA_Random/commit/169df7ace83760add13c121d5b4c337de72704fe', commit_message='Upload dataset', commit_description='', oid='169df7ace83760add13c121d5b4c337de72704fe', pr_url=None, pr_revision=None, pr_num=None)
